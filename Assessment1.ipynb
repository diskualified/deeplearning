# %% [markdown]
# <a href="https://colab.research.google.com/github/diskualified/deeplearning/blob/main/Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIT first ex

# %%
# !wget https://i.ytimg.com/vi/zQEepslWURk/mqdefault.jpg -O LeBronFace.jpg
# Out:
# --2023-02-09 16:51:03--  https://i.ytimg.com/vi/zQEepslWURk/mqdefault.jpg
# Resolving i.ytimg.com (i.ytimg.com)... 173.194.193.119, 173.194.194.119, 173.194.196.119, ...
# Connecting to i.ytimg.com (i.ytimg.com)|173.194.193.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15119 (15K) [image/jpeg]
# Saving to: ‘LeBronFace.jpg’
#
# LeBronFace.jpg      100%[===================>]  14.76K  --.-KB/s    in 0s
#
# 2023-02-09 16:51:03 (131 MB/s) - ‘LeBronFace.jpg’ saved [15119/15119]

# %%
from PIL import Image

# %%
img = Image.open('LeBronFace.jpg')

# %%
for i in range(100):
  for j in range(100):
    img.putpixel((i+800,j+500), (0,0,0,255))

display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2160x1080 at 0x7FE727EAE130>

# %%
# !nvidia-smi
# Out:
# Thu Feb  9 14:35:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    24W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
