# %% [markdown]
# <a href="https://colab.research.google.com/github/diskualified/deeplearning/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIT first assignment

# %%
# !wget https://media.timeout.com/images/105879336/750/422/image.jpg -O budapest.jpg
# Out:
# --2023-02-09 18:04:26--  https://media.timeout.com/images/105879336/750/422/image.jpg
# Resolving media.timeout.com (media.timeout.com)... 13.224.2.39, 13.224.2.79, 13.224.2.89, ...
# Connecting to media.timeout.com (media.timeout.com)|13.224.2.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83973 (82K) [image/jpeg]
# Saving to: ‘budapest.jpg’
#
# budapest.jpg        100%[===================>]  82.00K  --.-KB/s    in 0.009s
#
# 2023-02-09 18:04:26 (8.83 MB/s) - ‘budapest.jpg’ saved [83973/83973]

# %%
from PIL import Image

# %%
img = Image.open('budapest.jpg')

# %%
w, h = img.size
for i in range(30):
  for j in range(30):
    img.putpixel((w - i - 1, j), (0,0,0))

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x422 at 0x7F20792FCC40>

# %%
# !nvidia-smi
# Out:
# Thu Feb  9 14:35:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    24W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
